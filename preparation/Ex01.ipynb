# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/miokobayashii/summerschool2022/blob/main/preparation/Ex01.ipynb?hl=ja)

# %% [markdown]
# # Let's run a simple python program

# %%
print("Hello world!")

# %%
# LIST
fruit_list = ["apples", "bananas", "cherries", "grapes"]

# To check a type of a variable, we use the function  type() as follows:

print(type(fruit_list))

# %%
print(fruit_list[0])

# %%
a = list(range(0,100, 20))
print(a)

# %%
# for loops

for i in fruit_list:
  print( i , end=" ")

# %%
for i in range(0,100,5):
  print( i , end=" ")

# %%
# !python --version
# Out:
# Python 3.7.13
